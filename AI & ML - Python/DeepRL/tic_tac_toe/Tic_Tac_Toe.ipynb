# %%
# !pip install -U numpy open_spiel
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (1.22.4)
# Collecting numpy
#   Using cached numpy-1.24.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
# Requirement already satisfied: open_spiel in /usr/local/lib/python3.8/dist-packages (1.2)
# Requirement already satisfied: pip>=20.0.2 in /usr/local/lib/python3.8/dist-packages (from open_spiel) (22.0.4)
# Requirement already satisfied: scipy>=1.7.3 in /usr/local/lib/python3.8/dist-packages (from open_spiel) (1.7.3)
# Requirement already satisfied: attrs>=19.3.0 in /usr/local/lib/python3.8/dist-packages (from open_spiel) (22.2.0)
# Requirement already satisfied: absl-py>=0.10.0 in /usr/local/lib/python3.8/dist-packages (from open_spiel) (1.4.0)

# %%
# !python tic_tac_toe_qlearner.py --interactive_play=true
# Out:
# I0208 19:29:48.587131 140630849410880 rl_environment.py:183] Using game string: tic_tac_toe
# I0208 19:29:49.747774 140630849410880 tic_tac_toe_qlearner.py:164] Starting episode 0, win_rates [0.777 0.46 ], lose_rates [0.183 0.502] against random_agents
# I0208 19:29:51.165523 140630849410880 tic_tac_toe_qlearner.py:164] Starting episode 0, win_rates [1. 0.], lose_rates [0. 1.] against qlearning_agents
# I0208 19:30:04.623201 140630849410880 tic_tac_toe_qlearner.py:164] Starting episode 10000, win_rates [0.972 0.78 ], lose_rates [0.005 0.128] against random_agents
# I0208 19:30:06.353196 140630849410880 tic_tac_toe_qlearner.py:164] Starting episode 10000, win_rates [0. 0.], lose_rates [0. 0.] against qlearning_agents
# I0208 19:30:19.546663 140630849410880 tic_tac_toe_qlearner.py:164] Starting episode 20000, win_rates [0.973 0.81 ], lose_rates [0.    0.094] against random_agents
# I0208 19:30:21.642673 140630849410880 tic_tac_toe_qlearner.py:164] Starting episode 20000, win_rates [0. 0.], lose_rates [0. 0.] against qlearning_agents
# I0208 19:30:34.346220 140630849410880 tic_tac_toe_qlearner.py:164] Starting episode 30000, win_rates [0.985 0.86 ], lose_rates [0.    0.035] against random_agents
# I0208 19:30:36.717460 140630849410880 tic_tac_toe_qlearner.py:164] Starting episode 30000, win_rates [0. 0.], lose_rates [0. 0.] against qlearning_agents
# I0208 19:30:49.159460 140630849410880 tic_tac_toe_qlearner.py:164] Starting episode 40000, win_rates [0.977 0.863], lose_rates [0.012 0.015] against random_agents
# I0208 19:30:51.790881 140630849410880 tic_tac_toe_qlearner.py:164] Starting episode 40000, win_rates [0. 0.], lose_rates [0. 0.] against qlearning_agents
# I0208 19:31:04.250713 140630849410880 tic_tac_toe_qlearner.py:164] Starting episode 50000, win_rates [0.983 0.867], lose_rates [0.   0.02] against random_agents
# I0208 19:31:06.989140 140630849410880 tic_tac_toe_qlearner.py:164] Starting episode 50000, win_rates [0. 0.], lose_rates [0. 0.] against qlearning_agents
# I0208 19:31:18.995025 140630849410880 tic_tac_toe_qlearner.py:108]
# not won: -1.0
#
# state:
# [['.' '.' '.']
#  ['.' '0' '.']
#  ['.' '.' '.']]
#
#
# state:
# [['X' '.' '.']
#  ['.' '0' '.']
#  ['.' '.' '.']]
#
#
# state:
# [['X' '0' '.']
#  ['.' '0' '.']
#  ['.' '.' '.']]
#
#
# state:
# [['X' '0' '.']
#  ['.' '0' '.']
#  ['.' 'X' '.']]
#
#
# state:
# [['X' '0' '.']
#  ['0' '0' '.']
#  ['.' 'X' '.']]
#
#
# state:
# [['X' '0' '.']
#  ['0' '0' '.']
#  ['X' 'X' '.']]
#
#
# state:
# [['X' '0' '.']
#  ['0' '0' '0']
#  ['X' 'X' '.']]
#
# I0208 19:31:19.126809 140630849410880 tic_tac_toe_qlearner.py:108]
# not won: -1.0
#
# state:
# [['.' '.' '.']
#  ['.' '0' '.']
#  ['.' '.' '.']]
#
#
# state:
# [['X' '.' '.']
#  ['.' '0' '.']
#  ['.' '.' '.']]
#
#
# state:
# [['X' '0' '.']
#  ['.' '0' '.']
#  ['.' '.' '.']]
#
#
# state:
# [['X' '0' '.']
#  ['.' '0' '.']
#  ['.' 'X' '.']]
#
#
# state:
# [['X' '0' '.']
#  ['0' '0' '.']
#  ['.' 'X' '.']]
#
#
# state:
# [['X' '0' '.']
#  ['0' '0' '.']
#  ['X' 'X' '.']]
#
#
# state:
# [['X' '0' '.']
#  ['0' '0' '0']
#  ['X' 'X' '.']]
#
# I0208 19:31:19.493157 140630849410880 tic_tac_toe_qlearner.py:108]
# not won: -1.0
#
# state:
# [['.' '.' '.']
#  ['0' '.' '.']
#  ['.' '.' '.']]
#
#
# state:
# [['.' '.' '.']
#  ['0' 'X' '.']
#  ['.' '.' '.']]
#
#
# state:
# [['.' '.' '.']
#  ['0' 'X' '.']
#  ['.' '.' '0']]
#
#
# state:
# [['X' '.' '.']
#  ['0' 'X' '.']
#  ['.' '.' '0']]
#
#
# state:
# [['X' '.' '.']
#  ['0' 'X' '.']
#  ['.' '0' '0']]
#
#
# state:
# [['X' '.' 'X']
#  ['0' 'X' '.']
#  ['.' '0' '0']]
#
#
# state:
# [['X' '.' 'X']
#  ['0' 'X' '.']
#  ['0' '0' '0']]
#
# I0208 19:31:19.558748 140630849410880 tic_tac_toe_qlearner.py:108]
# not won: -1.0
#
# state:
# [['.' '.' '.']
#  ['0' '.' '.']
#  ['.' '.' '.']]
#
#
# state:
# [['.' '.' '.']
#  ['0' 'X' '.']
#  ['.' '.' '.']]
#
#
# state:
# [['.' '.' '.']
#  ['0' 'X' '.']
#  ['.' '.' '0']]
#
#
# state:
# [['X' '.' '.']
#  ['0' 'X' '.']
#  ['.' '.' '0']]
#
#
# state:
# [['X' '.' '.']
#  ['0' 'X' '.']
#  ['.' '0' '0']]
#
#
# state:
# [['X' '.' 'X']
#  ['0' 'X' '.']
#  ['.' '0' '0']]
#
#
# state:
# [['X' '.' 'X']
#  ['0' 'X' '.']
#  ['0' '0' '0']]
#
# I0208 19:31:19.883321 140630849410880 tic_tac_toe_qlearner.py:164] Starting episode 59999, win_rates [0.977 0.905], lose_rates [0.    0.008] against random_agents
# I0208 19:31:22.747864 140630849410880 tic_tac_toe_qlearner.py:164] Starting episode 59999, win_rates [0. 0.], lose_rates [0. 0.] against qlearning_agents
# I0208 19:31:22.749723 140630849410880 tic_tac_toe_qlearner.py:183] You are playing as O
# I0208 19:31:22.750314 140630849410880 tic_tac_toe_qlearner.py:189]
# agent suggests these actions with these probabilities:
# [[1. 0. 0.]
#  [0. 0. 0.]
#  [0. 0. 0.]]
# I0208 19:31:22.750914 140630849410880 tic_tac_toe_qlearner.py:193]
# [['.' '.' '.']
#  ['.' '0' '.']
#  ['.' '.' '.']]
# Choose an action from [1 2 3 4 6 7 8 9]:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/absl/app.py", line 308, in run
#     _run_main(main, args)
#   File "/usr/local/lib/python3.8/dist-packages/absl/app.py", line 254, in _run_main
#     sys.exit(main(argv))
#   File "tic_tac_toe_qlearner.py", line 194, in main
#     action = command_line_action(time_step)
#   File "tic_tac_toe_qlearner.py", line 68, in command_line_action
#     action_str = input()
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "tic_tac_toe_qlearner.py", line 214, in <module>
#     app.run(main)
#   File "/usr/local/lib/python3.8/dist-packages/absl/app.py", line 316, in run
#     if isinstance(exc, SystemExit) and not exc.code:
# KeyboardInterrupt
# ^C

# %%
# !python tic_tac_toe_qlearner.py --interactive_play=false >& result_3.txt
